# %%
import pandas as pd

# %%
import numpy as np

# %%
product = pd.read_csv(r'D:\2nd_project\Retails Analytics\products.csv')

# %%
product.head(50)
# Out:
#    product_id           product_name        category   brand  cost_price  \
# 0       P0000        BrandA Shoulder     Electronics  BrandC       52.75
# 1       P0001  BrandA Responsibility     Electronics  BrandD       11.20
# 2       P0002           BrandB Small     Electronics  BrandB      144.62
# 3       P0003        BrandD Continue         Apparel  BrandD      119.91
# 4       P0004          BrandA Indeed         Apparel  BrandD       71.35
# 5       P0005             BrandC Cut     Electronics  BrandA       79.09
# 6       P0006             BrandC Air  Home & Kitchen  BrandA      147.30
# 7       P0007           BrandD State     Electronics  BrandC      166.73
# 8       P0008          BrandC Growth         Apparel  BrandA       13.94
# 9       P0009            BrandC Keep     Electronics  BrandB      173.96
# 10      P0010          BrandD Reveal  Home & Kitchen  BrandB       77.19
# 11      P0011           BrandC Laugh     Electronics  BrandB      109.16
# ...

# %%
null_percentage = (product.isnull().sum() / len(product)) * 100
print(null_percentage)
# Out:
# product_id      0.000000
# product_name    0.000000
# category        0.000000
# brand           4.901961
# cost_price      0.000000
# unit_price      0.000000
# margin_pct      0.000000
# dtype: float64

# %%
product = product.dropna(subset=['brand'])

# %%
product.head(50)
# Out:
#    product_id           product_name        category   brand  cost_price  \
# 0       P0000        BrandA Shoulder     Electronics  BrandC       52.75
# 1       P0001  BrandA Responsibility     Electronics  BrandD       11.20
# 2       P0002           BrandB Small     Electronics  BrandB      144.62
# 3       P0003        BrandD Continue         Apparel  BrandD      119.91
# 4       P0004          BrandA Indeed         Apparel  BrandD       71.35
# 5       P0005             BrandC Cut     Electronics  BrandA       79.09
# 6       P0006             BrandC Air  Home & Kitchen  BrandA      147.30
# 7       P0007           BrandD State     Electronics  BrandC      166.73
# 8       P0008          BrandC Growth         Apparel  BrandA       13.94
# 9       P0009            BrandC Keep     Electronics  BrandB      173.96
# 10      P0010          BrandD Reveal  Home & Kitchen  BrandB       77.19
# 11      P0011           BrandC Laugh     Electronics  BrandB      109.16
# ...

# %%
product.duplicated(subset=['product_id']).sum()
# Out:
# np.int64(0)

# %%
product= product.drop_duplicates(subset=['product_id'])

# %%
product.dtypes
# Out:
# product_id       object
# product_name     object
# category         object
# brand            object
# cost_price      float64
# unit_price      float64
# margin_pct      float64
# dtype: object

# %%
product[['unit_price','cost_price']].dtypes
# Out:
# unit_price    float64
# cost_price    float64
# dtype: object

# %%
product['Price_Tier'] = pd.cut(
    product['unit_price'],
    bins=[0, 100, 200, float('inf')],
    labels=['Budget', 'Mid-Range', 'Premium']
)

# %%
product.head(50)
# Out:
#    product_id           product_name        category   brand  cost_price  \
# 0       P0000        BrandA Shoulder     Electronics  BrandC       52.75
# 1       P0001  BrandA Responsibility     Electronics  BrandD       11.20
# 2       P0002           BrandB Small     Electronics  BrandB      144.62
# 3       P0003        BrandD Continue         Apparel  BrandD      119.91
# 4       P0004          BrandA Indeed         Apparel  BrandD       71.35
# 5       P0005             BrandC Cut     Electronics  BrandA       79.09
# 6       P0006             BrandC Air  Home & Kitchen  BrandA      147.30
# 7       P0007           BrandD State     Electronics  BrandC      166.73
# 8       P0008          BrandC Growth         Apparel  BrandA       13.94
# 9       P0009            BrandC Keep     Electronics  BrandB      173.96
# 10      P0010          BrandD Reveal  Home & Kitchen  BrandB       77.19
# 11      P0011           BrandC Laugh     Electronics  BrandB      109.16
# ...

# %%
product.to_csv('sql_product.csv', index=False)
print("Product data cleaned with age_group!")
# Out:
# Product data cleaned with age_group!
